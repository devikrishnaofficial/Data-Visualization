# %%
# library & dataset
# library
import numpy as np
import matplotlib.pyplot as plt

# Create data
x=range(1,6)
y=[1,4,6,8,4]

# Area plot
plt.fill_between(x, y)
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 12
#      10 # Area plot
#      11 plt.fill_between(x, y)
# ---> 12 plot.show()
#
# NameError: name 'plot' is not defined
