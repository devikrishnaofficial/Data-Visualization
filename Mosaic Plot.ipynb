# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dp = pd.read_excel('C:/Users/devik/Data Visualization/mark.xlsx')
dp
# Out:
#     Student id  Physics  Maths  English  Science Gender  Pass/Fail
# 0            1       98     98       98       98      m          1
# 1            2       98     98       67       67      m          1
# 2            3       95     95       54       54      m          1
# 3            4       66     66       67       67      f          1
# 4            5       76     76       98       98      f          1
# ..         ...      ...    ...      ...      ...    ...        ...
# 95          96       97     86       66       95      m          1
# 96          97       93     85       76       96      m          1
# 97          98       94     86       86       97      m          1
# 98          99       65     97       96       84      f          1
# 99         100       65     93       39       86      f          1
#
# [100 rows x 7 columns]

# %%
from statsmodels.graphics.mosaicplot import mosaic

# Convert Pass/Fail to categorical for mosaic plot
dp['Pass/Fail'] = dp['Pass/Fail'].replace({0: 'Fail', 1: 'Pass'})

# Plot mosaic plot
plt.figure(figsize=(10, 8))
mosaic(dp, ['Gender', 'Pass/Fail'], title='Mosaic Plot of Gender and Pass/Fail')
plt.show()
